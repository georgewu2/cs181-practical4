# %%
import numpy as np
import pandas as pd
import scipy as sp
import sklearn
import random
from matplotlib import pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 7.5)

# %%
scores = [-10.0,-10.0,-10.0,-5.0,-5.0,-5.0,-10.0,-9.0,-5.0,-3.0,-5.0,-5.0,-1.0,-4.0,-9.0,-2.0,-5.0,-9.0,-1.0,-7.0,-2.0,-4.0,-5.0,-4.0,3.0,26.0,4.0,2.0,-2.0,-4.0,-9.0,14.0,12.0,21.0,29.0,-3.0,145.0,10.0,-4.0,50.0,0.0,15.0,1.0,4.0,11.0,44.0,19.0,0.0,-5.0,19.0,71.0,3.0,108.0,0.0,1.0,76.0,25.0,-5.0,45.0,10.0,26.0,92.0,-5.0,20.0,3.0,7.0,11.0,-4.0,11.0,7.0,-2.0,4.0,-4.0,-5.0,-1.0,0.0,-2.0,0.0,-4.0,-4.0,-4.0,-5.0,-5.0,-3.0,-4.0,-8.0,-5.0, -3.0, -5.0, -4.0,-5.0,-10.0,-5.0,-2.0,-5.0,0.0,-4.0,-4.0,-3.0,-2.0]
np.mean(scores[0:76])
# Out:
# 10.013157894736842

# %%
scorese = np.genfromtxt ('score_history.csv', delimiter=",")
print np.mean(scorese)
# Out:
# -1.62

# %%
plt.plot(range(0,150), scorese)

# %%
plt.plot(range(0,77), scores)

# %%
plt.plot([0.25,0.5,0.75,1], [74.54, 63.025, 1.74, 10.013])

# %%
scorese = np.genfromtxt ('practical4-code/score_history.csv', delimiter=",")
print np.mean(scorese)
# Out:
# 31.9533333333

# %%
plt.plot(range(0,150), scorese)

# %%
scorese = np.genfromtxt ('practical4-code/score_history.csv', delimiter=",")
print np.mean(scorese)
plt.plot(range(0,150), scorese)
# Out:
# 20.37
# ...

# %%
scorese = np.genfromtxt ('practical4-code/score_history_75.csv', delimiter=",")
print np.mean(scorese)
plt.plot(range(0,150), scorese)
# Out:
# 16.57
# ...

# %%
scorese = np.genfromtxt ('practical4-code/score_history_75.csv', delimiter=",")
print np.mean(scorese)
plt.plot(range(0,150), scorese)
# Out:
# 19.8178807947
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-b27a78673e1d> in <module>()
#       1 scorese = np.genfromtxt ('practical4-code/score_history_75.csv', delimiter=",")
#       2 print np.mean(scorese)
# ----> 3 plt.plot(range(0,150), scorese)
#
# /Users/georgieewuu/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3091         ax.hold(hold)
#    3092     try:
# -> 3093         ret = ax.plot(*args, **kwargs)
#    3094         draw_if_interactive()
#    3095     finally:
#
# /Users/georgieewuu/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1371         lines = []
#    1372
# -> 1373         for line in self._get_lines(*args, **kwargs):
#    1374             self.add_line(line)
#    1375             lines.append(line)
#
# ...
